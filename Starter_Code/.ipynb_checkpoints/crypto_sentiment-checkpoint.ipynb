# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
from nltk.corpus import stopwords
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\mattr\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv()
key = os.getenv('NEWSAPI')


# YOUR CODE HERE!

# %%
# Create a newsapi client
news = NewsApiClient(api_key=key)
# YOUR CODE HERE!

# %%
# Fetch the Bitcoin news articles
articles_btc = news.get_everything(q='Bitcoin', language='en')
# YOUR CODE HERE!

# %%
# Fetch the Ethereum news articles
articles_eth = news.get_everything(q='Ethereum', language='en')

# articles_eth
# YOUR CODE HERE!

# %%
# Create the Bitcoin sentiment scores DataFrame
btc_sentiments = []
for article in articles_btc["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        btc_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass

btc_df = pd.DataFrame(btc_sentiments)
btc_df
# YOUR CODE HERE!
# Out:
#                                                  text        date  compound  \
# 0   When Russia invaded Ukraine, Niki Proshin was ...  2022-03-17    0.0000
# 1   "Bitcoin was seen by many of its libertarian-l...  2022-03-12   -0.7713
# 2   Feb 22 (Reuters) - Bitcoin miners are feeling ...  2022-02-22   -0.1779
# 3   March 1 (Reuters) - Bitcoin has leapt since Ru...  2022-03-01    0.0000
# 4   Whose side is cryptocurrency on? If you had as...  2022-03-08   -0.3182
# 5   Getty\r\nWelcome to Nonfungible Tidbits. Our f...  2022-03-05   -0.6808
# 6   Here's what happened this week in the crypto w...  2022-03-19    0.4588
# 7   An appeals court decided shilling for an unreg...  2022-02-19    0.3400
# 8   Nurphoto/Getty\r\nAs Russia launched an invasi...  2022-02-28    0.1280
# 9   LONDON, March 4 (Reuters) - Cryptocurrencies h...  2022-03-04   -0.1280
# 10  March 15 (Reuters) - Bitcoin loves flirting wi...  2022-03-15    0.3182
# ...

# %%
# Create the Ethereum sentiment scores DataFrame
# YOUR CODE HERE!
eth_sentiments = []
for article in articles_eth["articles"]:
    try:
        text = article["content"]
        date = article["publishedAt"][:10]
        sentiment = analyzer.polarity_scores(text)
        compound = sentiment["compound"]
        pos = sentiment["pos"]
        neu = sentiment["neu"]
        neg = sentiment["neg"]
        
        eth_sentiments.append({
            "text": text,
            "date": date,
            "compound": compound,
            "positive": pos,
            "negative": neg,
            "neutral": neu
            
        })
        
    except AttributeError:
        pass
eth_df = pd.DataFrame(eth_sentiments)
eth_df
# Out:
#                                                  text        date  compound  \
# 0   In February, shit hit the fan in the usual way...  2022-03-01   -0.3182
# 1   Coinbase reported that the share of trading vo...  2022-02-25    0.6705
# 2   Illustration by James Bareham / The Verge\r\n\...  2022-02-26   -0.4588
# 3   If it sounds too good to be true, youre not wr...  2022-03-13    0.8340
# 4   It seems that in 2022, you cant escape from th...  2022-03-03   -0.1326
# 5   The cryptocurrency boom over the past few year...  2022-03-02    0.0000
# 6   A version of this article was published in TIM...  2022-02-24    0.0000
# 7   Joe Biden is dipping his toes into crypto. On ...  2022-03-09    0.5267
# 8   The cryptocurrency boom over the past few year...  2022-03-16    0.0000
# 9   The cryptocurrency boom over the past few year...  2022-03-09    0.0000
# 10  If blockchain technology is to reach true mass...  2022-03-07    0.7722
# ...

# %%
# Describe the Bitcoin Sentiment

# YOUR CODE HERE!
btc_df.describe()
# Out:
#         compound   positive   negative    neutral
# count  20.000000  20.000000  20.000000  20.000000
# mean    0.001295   0.047700   0.043750   0.908500
# std     0.406381   0.045767   0.061198   0.071992
# min    -0.771300   0.000000   0.000000   0.739000
# 25%    -0.231275   0.000000   0.000000   0.861500
# 50%     0.000000   0.051500   0.000000   0.918000
# 75%     0.345300   0.075750   0.071000   0.952500
# max     0.636900   0.152000   0.187000   1.000000

# %%
# Describe the Ethereum Sentiment
# YOUR CODE HERE!
eth_df.describe()
# Out:
#         compound   positive  negative   neutral
# count  20.000000  20.000000  20.00000  20.00000
# mean    0.190925   0.078750   0.02975   0.89145
# std     0.401422   0.085383   0.04006   0.10092
# min    -0.526700   0.000000   0.00000   0.69200
# 25%     0.000000   0.000000   0.00000   0.84100
# 50%     0.025800   0.066500   0.00000   0.91050
# 75%     0.514625   0.120500   0.06125   1.00000
# max     0.834000   0.249000   0.11500   1.00000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Ethereum
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum
#
# Q. Which coin had the highest positive score?
#
# A: Ethereum

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
# YOUR CODE HERE!
lem = WordNetLemmatizer()
# Create a list of stopwords
stop_words = set(stopwords.words('english'))
# YOUR CODE HERE!

# Expand the default stopwords list if necessary
# YOUR CODE HERE!
# stopwords.append('char')

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    # Remove the punctuation from text
    print(text)
    res = re.sub(r'[^\w\s]', '', text)

   
    # Create a tokenized list of the words
    words = word_tokenize(res)
    print(words)
    
    # Lemmatize words into root words
    words_lem = [lem.lemmatize(i) for i in words]

   
    # Convert the words to lowercase
    words_lem = [i.lower() for i in words_lem]
    
    # Remove the stop words
    tokens = [i for i in words_lem if i not in stop_words]
    
    
    return tokens

# %%
# Create a new tokens columne for Bitcoin
string = ''
for i in articles_btc['articles']: 
    # print(i['content'])
    string = string + i['content']
string
tokens = tokenizer(string)
tokens_btc = [tokenizer(i['content']) for i in articles_btc['articles']]
# tokens[0]
btc_df['tokens'] = tokens_btc
# btc_df
# YOUR CODE HERE!
# Out:
# When Russia invaded Ukraine, Niki Proshin was already a year into making a living as a vlogger — he had a YouTube channel, a TikTok channel, and an Instagram. He also ran an online Russian club for a… [+5883 chars]"Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance," argues a columnist in the New York Times, "a form of 'digital gold' that would be a source of stability as … [+3914 chars]Feb 22 (Reuters) - Bitcoin miners are feeling the heat - and the pain's rippling downstream to pressure prices.
# The cryptocurrency's spectacular rally in 2021 drew thousands of entrants into mining,… [+4196 chars]March 1 (Reuters) - Bitcoin has leapt since Russia's invasion of Ukraine, bolstered by people in those countries looking to store and move money in anonymous and decentralised crypto.
# ...

# %%
# Create a new tokens column for Ethereum
# YOUR CODE HERE!
tokens = [tokenizer(i['content']) for i in articles_btc['articles']]
string_eth = ''
for i in articles_eth['articles']: 
    # print(i['content'])
    string_eth = string_eth + i['content']

tokens_str = tokenizer(string_eth)
eth_df['tokens'] = tokens
eth_df
# Out:
# When Russia invaded Ukraine, Niki Proshin was already a year into making a living as a vlogger — he had a YouTube channel, a TikTok channel, and an Instagram. He also ran an online Russian club for a… [+5883 chars]
# ['When', 'Russia', 'invaded', 'Ukraine', 'Niki', 'Proshin', 'was', 'already', 'a', 'year', 'into', 'making', 'a', 'living', 'as', 'a', 'vlogger', 'he', 'had', 'a', 'YouTube', 'channel', 'a', 'TikTok', 'channel', 'and', 'an', 'Instagram', 'He', 'also', 'ran', 'an', 'online', 'Russian', 'club', 'for', 'a', '5883', 'chars']
# "Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance," argues a columnist in the New York Times, "a form of 'digital gold' that would be a source of stability as … [+3914 chars]
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the Bitcoin N-grams where N=2
n_btc = ngrams(tokens, n=2)
arr = [ ' '.join(grams) for grams in n_btc]
# YOUR CODE HERE!
print(arr)
# Out:
# ['russia invaded', 'invaded ukraine', 'ukraine niki', 'niki proshin', 'proshin wa', 'wa already', 'already year', 'year making', 'making living', 'living vlogger', 'vlogger youtube', 'youtube channel', 'channel tiktok', 'tiktok channel', 'channel instagram', 'instagram also', 'also ran', 'ran online', 'online russian', 'russian club', 'club 5883', '5883 charsbitcoin', 'charsbitcoin wa', 'wa seen', 'seen many', 'many libertarianleaning', 'libertarianleaning fan', 'fan kind', 'kind doomsday', 'doomsday insurance', 'insurance argues', 'argues columnist', 'columnist new', 'new york', 'york times', 'times form', 'form digital', 'digital gold', 'gold would', 'would source', 'source stability', 'stability 3914', '3914 charsfeb', 'charsfeb 22', '22 reuters', 'reuters bitcoin', 'bitcoin miner', 'miner feeling', 'feeling heat', 'heat pain', 'pain rippling', 'rippling downstream', 'downstream pressure', 'pressure price', 'price cryptocurrencys', 'cryptocurrencys spectacular', 'spectacular rally
# ...

# %%
# Generate the Ethereum N-grams where N=2
n_eth = ngrams(tokens_str, n=2)
arr_eth = [ ' '.join(grams) for grams in n_eth]

# YOUR CODE HERE!

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top_ten_btc = token_count(arr, 10)
top_ten_btc
# YOUR CODE HERE!
# Out:
# [('reuters bitcoin', 3),
#  ('russia invaded', 2),
#  ('invaded ukraine', 2),
#  ('welcome nonfungible', 2),
#  ('nonfungible tidbits', 2),
#  ('since russia', 2),
#  ('charssan salvador', 2),
#  ('reuters el', 2),
#  ('el salvador', 2),
#  ('central american', 2)]

# %%
# Use token_count to get the top 10 words for Ethereum
top_ten_eth = token_count(arr_eth, 10)
top_ten_eth
# YOUR CODE HERE!
# Out:
# [('charsthe cryptocurrency', 3),
#  ('cryptocurrency boom', 3),
#  ('boom past', 3),
#  ('past year', 3),
#  ('year ha', 3),
#  ('ha helped', 3),
#  ('helped propel', 3),
#  ('propel newer', 3),
#  ('newer market', 3),
#  ('market record', 3)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
# YOUR CODE HERE!
cloud_btc = WordCloud().generate(string)
plt.imshow(cloud_btc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Generate the Ethereum word cloud
cloud_eth = WordCloud().generate(string_eth)
plt.imshow(cloud_eth, interpolation='bilinear')
plt.axis("off")
plt.show()
# YOUR CODE HERE!

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      --------------------------------------- 13.9/13.9 MB 11.1 MB/s eta 0:00:00
# ...
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc = nlp(string)

# Add a title to the document
# YOUR CODE HERE!
# Out:
# When Russia invaded Ukraine, Niki Proshin was already a year into making a living as a vlogger — he had a YouTube channel, a TikTok channel, and an Instagram. He also ran an online Russian club for a… [+5883 chars]"Bitcoin was seen by many of its libertarian-leaning fans as a kind of doomsday insurance," argues a columnist in the New York Times, "a form of 'digital gold' that would be a source of stability as … [+3914 chars]Feb 22 (Reuters) - Bitcoin miners are feeling the heat - and the pain's rippling downstream to pressure prices.
# The cryptocurrency's spectacular rally in 2021 drew thousands of entrants into mining,… [+4196 chars]March 1 (Reuters) - Bitcoin has leapt since Russia's invasion of Ukraine, bolstered by people in those countries looking to store and move money in anonymous and decentralised crypto.
# ...

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">When
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  invaded
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ukraine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Niki Proshin
# ...

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc.ents if ent.label_ == 'GPE'])
# Out:
# ['Russia', 'Ukraine', 'Russia', 'Ukraine', 'Russia', 'Ukraine', 'Getty', 'Russia', 'Mexico City', 'Russia', 'Ukraine', 'Russia', 'U.S.', 'documents</li></ul', 'Ukraine', 'El Salvador', 'El Salvador', 'San Jose', 'Ukrainian', 'Russia']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
# YOUR CODE HERE!
doc_eth = nlp(string_eth)
# Add a title to the document
# YOUR CODE HERE!

# %%
# Render the visualization
# YOUR CODE HERE!
displacy.render(doc_eth, style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     February
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , shit hit the fan in the usual way: An old tweet resurfaced. Brantly Millegan, director of operations at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Ethereum Name Service
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ENS
# ...

# %%
# List all Entities
# YOUR CODE HERE!
print([ent.text for ent in doc_eth.ents if ent.label_ == 'GPE'])
# Out:
# ['Ukrainian', 'Russia', 'US', 'Russia', 'Ukraine', 'Russia', 'Ukraine', 'Russia', 'Russia', 'Ukraine', 'Bloomberg', 'Getty Images']

# %% [markdown]
# ---
